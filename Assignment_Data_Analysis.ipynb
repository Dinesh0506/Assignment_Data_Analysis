# %%
import pandas as pd

# %%
dataset=pd.read_csv('Placement.csv')

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# #check the how many null values are present inn dataset
# dataset.isna().sum()

# %% [markdown]
# #1.Replace the NAN values to correct values.and Justify why you have to chosen the same?
# #Solution:-
# #in salary column have 67 Nan values in the dataset
# #we can replace the null with zero.
# #why means if i give 0 to null value it not affect the  whole dataset.
# #we get it preprocessed dataset.

# %%
#Just Replace the NAN_Values to Zero as required
dataset["salary"].fillna(0,inplace=True)
# Out:
# C:\Windows\Temp\ipykernel_8060\2091879740.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["salary"].fillna(0,inplace=True)

# %%
#Again Check is NAN values present or not
dataset.isna().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
#View the dataset table
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#2.How many of them not Placement? ----> 67 Students are Not Placed
df=[]
for i in dataset["status"]:
    if i =="Not Placed":
        df.append(i)

# %%
len(df)
# Out:
# 67

# %% [markdown]
# #3.Find the Reason For non placement from dataset?

# %%
#create a function
def quanQual(dataset):
    quan=[]
    qual=[]
    for columnName in dataset.columns:
         if(dataset[columnName].dtype=='O'):
          #print("qual")
          qual.append(columnName)
         else:
          #print("quan")
          quan.append(columnName)
    return quan,qual

# %%
quan,Qual=quanQual(dataset)

# %%
quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
Qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
df=[]
for i in dataset["status"]:
    if i =="Not Placed":
        descriptive=pd.DataFrame(index=["mean"],columns=quan)
        for columnName in quan:
            descriptive[columnName]["mean"]=dataset[columnName].mean()
            df.append(descriptive)
# Out:
# C:\Windows\Temp\ipykernel_8060\4196232298.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[columnName]["mean"]=dataset[columnName].mean()
# ...

# %%
Descriptive=pd.DataFrame(index=["mean"],columns=df)

# %%
descriptive
# Out:
#       sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# mean  108.0  67.303395  66.333163  66.370186  72.100558  62.278186
#
#              salary
# mean  198702.325581

# %% [markdown]
# # Based on 10th,12th,Degree,MBA pass marks are Average only student performance then only not get placed.

# %%
#4.What is Relation between Salary and Mba_p?
dataset.corr(numeric_only=True)
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.002543
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.002543  0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %% [markdown]
# #Here the relation between salary and mba_p is 0.139823.then it is low degree postive Corelation

# %% [markdown]
# #5.Which Specialization in getting minimum salary?

# %%
df=dataset.loc[:,["specialisation","salary"]]

# %%
pd.DataFrame.min(df)
# Out:
# specialisation    Mkt&Fin
# salary                0.0
# dtype: object

# %%
#6. How many of them getting above 500000 salary? --> 3
student=[]
for i in dataset["salary"]:
    if i >500000:
        student.append(i)
len(student)
# Out:
# 3

# %% [markdown]
# #7.Test the Analysis of variance between etest_p and mba_p at significance level 5%(make decision in hypothesis testng)

# %%
#Dependent Sample--> Paired T_Test
#same Group(Male)and diferent condition(etest_p,mba_p)
from scipy.stats import ttest_rel
Male=dataset[dataset["gender"]=="M"]["etest_p"]
Male1=dataset[dataset["gender"]=="M"]["mba_p"]
ttest_rel(Male,Male1)
# Out:
# TtestResult(statistic=10.558377508518305, pvalue=1.8140319084982095e-19, df=138)

# %% [markdown]
# #Solution:-
# #Rejected Null Hypothesis  p<0.05
# #in this p value is 1.81 then  it accept the null hypothesis and rejected Alternate Hypotheis testing.

# %% [markdown]
# #8.Test the similarity between the degree(sci&tech) and  speciliasation (mkt&hr) with respect to salary at
# #significance level 5%(make decision in hypothesis testng) ?

# %%
#T_Test
#Independent Sample-Unpaired T Test
#Different Group(degree_t(Sci&Tech,Comm&Mgmt)) but Same Condition(Salary)
from scipy.stats import ttest_ind
Male=dataset[dataset["degree_t"]=="Sci&Tech"]["salary"]
Male1=dataset[dataset["degree_t"]=="Comm&Mgmt"]["salary"]
ttest_ind(Male,Male1)
# Out:
# TtestResult(statistic=0.9483890659956673, pvalue=0.3440646361895928, df=202.0)

# %%
#T_Test
#Independent Sample-Unpaired T Test
#Different Group(specialisation(Mkt&HR,Mkt&Fin)) but Same Condition(Salary)
from scipy.stats import ttest_ind
Male=dataset[dataset["specialisation"]=="Mkt&HR"]["salary"]
Male1=dataset[dataset["specialisation"]=="Mkt&Fin"]["salary"]
ttest_ind(Male,Male1)
# Out:
# TtestResult(statistic=-4.187025573022164, pvalue=4.1363454894317164e-05, df=213.0)

# %% [markdown]
# #Solution:
# # In this degree_t is similiearity with salary  P value is 0.3.
# #Then Rejected the NULL Hypothesis and accept the Alternate Hypothesis.
# #But In Specilisation have similierarity with salary p value is 4.13.
# #Then Rejected the Alternate Hypothesis and accept the NULL Hypothesis.

# %% [markdown]
# #9. Convert the Normal Distribution to Standard Normal Distribution for salary Column?

# %%
#Create a Standard Normal Distribution
def stdNBgraph(dataset):
    #importing the libary
    import seaborn as sns
    #Calculate the mean value for dataset
    mean=dataset.mean()
    #Calculate the standard deivation for dataset 
    std=dataset.std()
    #assiging the values to list in i variable
    values=[i for i in dataset]
    #calculate the Z_score for the dataset
    z_score=[((j-mean)/std) for j in values]
    #show the graph based on Z_Score values
    sns.distplot(z_score,kde=True)
    
    sum(z_score)/len(z_score)

# %%
stdNBgraph(dataset["salary"])
# Out:
# C:\Windows\Temp\ipykernel_8060\2679438392.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(z_score,kde=True)

# %% [markdown]
# #10. what is the probability  Density function  of salary range from 700000 to 900000?

# %%
def get_pdf_probability(dataset,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
    pyplot.axvline(startrange,color='Red')
    pyplot.axvline(endrange,color='Red')
    # generate a sample
    sample = dataset
    # calculate parameters
    sample_mean =sample.mean()
    sample_std = sample.std()
    print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))
    # define the distribution
    dist = norm(sample_mean, sample_std)
    
    # sample probabilities for a range of outcomes
    values = [value for value in range(startrange, endrange)]
    probabilities = [dist.pdf(value) for value in values]    
    prob=sum(probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
get_pdf_probability(dataset["salary"],700000,900000)
# Out:
# C:\Windows\Temp\ipykernel_8060\132380739.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
# Mean=198702.326, Standard Deviation=154780.927
# The area between range(700000,900000):0.0005973310593974868
# 0.0005973310593974868

# %% [markdown]
# #11.Test the similarity between the degree(sci&tech)with respect to Etest_p and Mba_p at
# #significance level 5%(make decision in hypothesis testng)?

# %%
#Dependent Sample--> Paired T_Test
#same Group(degree(sci&tech))and diferent condition(etest_p,mba_p)
from scipy.stats import ttest_rel
Male=dataset[dataset["degree_t"]=="Sci&Tech"]["etest_p"]
Male1=dataset[dataset["degree_t"]=="Sci&Tech"]["mba_p"]
ttest_rel(Male,Male1)
# Out:
# TtestResult(statistic=5.0049844583693615, pvalue=5.517920600505392e-06, df=58)

# %% [markdown]
# #Solution:
# # In this degree_t is similiearity with salary  P value is 5.51.
# #Then Rejected the Alternate Hypothesis and accept the Null Hypothesis.

# %% [markdown]
# #12.Which is highly correlted with Salary?

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def  calc_vif(x):
    #calculating vif 
    vif=pd.DataFrame()
    vif["variables"]=x.columns
    vif["VIF"]=[variance_inflation_factor(x.values,i)for i in range(x.shape[1])]
    return (vif)

# %%
calc_vif(dataset[["ssc_p","hsc_p","degree_p","mba_p","salary"]])
# Out:
#   variables         VIF
# 0     ssc_p   75.793832
# 1     hsc_p   58.226703
# 2  degree_p  111.229738
# 3     mba_p  107.618037
# 4    salary    3.930220

# %% [markdown]
# ##Solution:
# # In this degree_p is highly correlated to Salary Column.

# %% [markdown]
# #13. Plot the Any graph and Explain it?

# %%
import  numpy as np 
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Categorical Data and Numberical  data polt ---> status and salary
import seaborn as sns
sns.stripplot(x="status",y="salary",data=dataset)
# Out:
# <Axes: xlabel='status', ylabel='salary'>

# %% [markdown]
# #Solution:-
# In Above Graph says how many students are get placed with good salary.and remaining students not placed with no salary.
